# %% [markdown]
# # Car Brand Classification

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Preprocessing

# %%
data=pd.read_csv("cars.csv")

# %%
data
# Out:
#       mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0    14.0           8          350  165       4209           12   1972
# 1    31.9           4           89   71       1925           14   1980
# 2    17.0           8          302  140       3449           11   1971
# 3    15.0           8          400  150       3761           10   1971
# 4    30.5           4           98   63       2051           17   1978
# 5    23.0           8          350  125       3900           17   1980
# 6    13.0           8          351  158       4363           13   1974
# 7    14.0           8          440  215       4312            9   1971
# 8    25.4           5          183   77       3530           20   1980
# 9    37.7           4           89   62       2050           17   1982
# 10   34.0           4          108   70       2245           17   1983
# 11   34.3           4           97   78       2188           16   1981
# ...

# %% [markdown]
# ### Removing Empty String Values

# %%
 data.replace(' ', np.nan, inplace=True)
data=data.dropna()

# %%
list(data)
# Out:
# ['mpg',
#  ' cylinders',
#  ' cubicinches',
#  ' hp',
#  ' weightlbs',
#  ' time-to-60',
#  ' year',
#  ' brand']

# %%
features=['mpg', ' cylinders', ' cubicinches', ' hp', ' weightlbs', ' time-to-60', ' year'] 
Y=data[' brand']
X=data[features]

# %%
def myencoding(column):
    C=column
    if (C==' Europe.'):
        return 'E'
    if (C==' US.'):
        return 'U'
    else:
        return 'J'

# %%
Y=Y.apply(myencoding)
Y.head()
# Out:
# 0    U
# 1    E
# 2    U
# 3    U
# 4    U
# Name:  brand, dtype: object

# %% [markdown]
# ## The Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn import metrics

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1)

# %%
model=DecisionTreeClassifier(criterion='gini')
model=model.fit(X_train,Y_train)

# %% [markdown]
# ### Prediction

# %%
y_pred=model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(Y_test, y_pred))
# Out:
# Accuracy: 0.8461538461538461

# %% [markdown]
# #### Similarly try using other algorithms from scikit-learn to train your model and see how the accuracy changes for each model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = pd.read_csv(r'/Users/ashwinsasikumar/Desktop/Sample.csv')
print(x)
# Out:
#      1   5
# 0    2   7
# 1    3   8
# 2    4   3
# 3    5   5
# 4    6   6
# 5    7   3
# 6    8   7
# 7    9   2
# 8   10  12
# 9   11   5
# 10  12   7
# 11  13   2
# 12  14   6
# 13  15   9
# 14  16   2

# %%
x.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Sample.csv')

# %%
data.head()
# Out:
#    1  5
# 0  2  7
# 1  3  8
# 2  4  3
# 3  5  5
# 4  6  6

# %%
plt.figure(figsize = (14,14))
plt.style.use('fivethirtyeight')
plt.grid(color='white')
plt.title('Epic Info')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.plot(data['1'],data['5'],color='red')

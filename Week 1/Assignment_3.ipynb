# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1,17)
y = np.array([5,7,8,3,5,6,3,7,2,12,5,7,2,6,9,2])
plt.style.use("ggplot")
plt.plot(x,y,"r")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("There u go")
plt.show()
